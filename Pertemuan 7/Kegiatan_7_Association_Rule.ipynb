# %%
import pandas as pd
from openpyxl import load_workbook

# %%
df =  pd.read_excel('swalayan.xlsx')
df
# Out:
#       No                 Nama  Roti Unnamed: 3 Selai Unnamed: 5 Susu  \
# 0    NaN                   NaN   Ya      Tidak    Ya      Tidak   Ya
# 1    1.0      Puguh Drajat E.P    v        NaN   NaN          v    v
# 2    2.0  Arsyad Cahya Subrata  NaN          v   NaN          v    v
# 3    3.0          Yesi Novela   NaN        NaN   NaN          v  NaN
# 4    4.0       Pandu Herwijaya  NaN          v   NaN        NaN    v
# 5    5.0        Anjar Prasetyo    v        NaN     v        NaN  NaN
# 6    6.0   Moh. Dadi Kurniawan    v        NaN   NaN        NaN    v
# 7    7.0        Martin Sarlina    v        NaN     v        NaN  NaN
# 8    8.0      Yan Adhi Permadi    v        NaN     v        NaN  NaN
# 9    9.0       Achicha Wahyuni  NaN        NaN   NaN        NaN  NaN
# 10  10.0   Yayan Tisna Permadi  NaN          v   NaN          v  NaN
# 11  11.0           Ani Yuanita  NaN        NaN   NaN          v    v
# 12  12.0       Burhan Fajar P.    v        NaN     v        NaN    v
# 13  13.0        Heri Budiyanto  NaN          v   NaN        NaN    v
# 14  14.0       Dimas Satrio W.  NaN          v   NaN          v  NaN
# 15  15.0           Nur Hidayat  NaN          v   NaN        NaN    v
#
#    Unnamed: 7 Mentega Unnamed: 9
# 0       Tidak      Ya      Tidak
# 1         NaN     NaN          v
# 2         NaN     NaN          v
# 3           v     NaN          v
# 4         NaN     NaN        NaN
# 5         NaN       v        NaN
# 6         NaN       v        NaN
# 7           v       v        NaN
# 8           v     NaN        NaN
# 9         NaN     NaN        NaN
# 10          v     NaN          v
# 11        NaN     NaN        NaN
# 12        NaN       v        NaN
# 13        NaN     NaN          v
# 14          v     NaN        NaN
# 15        NaN     NaN        NaN

# %%
df.columns = ['No', 'Nama', 'ROTI[Y]', 'ROTI[T]', 'SELAI[Y]', 'SELAI[T]', 'SUSU[Y]', 'SUSU[T]', 'MENTEGA[Y]', 'MENTEGA[T]']
df
# Out:
#       No                  Nama ROTI[Y] ROTI[T] SELAI[Y] SELAI[T] SUSU[Y]  \
# 0    NaN                   NaN      Ya   Tidak       Ya    Tidak      Ya
# 1    1.0      Puguh Drajat E.P       v     NaN      NaN        v       v
# 2    2.0  Arsyad Cahya Subrata     NaN       v      NaN        v       v
# 3    3.0          Yesi Novela      NaN     NaN      NaN        v     NaN
# 4    4.0       Pandu Herwijaya     NaN       v      NaN      NaN       v
# 5    5.0        Anjar Prasetyo       v     NaN        v      NaN     NaN
# 6    6.0   Moh. Dadi Kurniawan       v     NaN      NaN      NaN       v
# 7    7.0        Martin Sarlina       v     NaN        v      NaN     NaN
# 8    8.0      Yan Adhi Permadi       v     NaN        v      NaN     NaN
# 9    9.0       Achicha Wahyuni     NaN     NaN      NaN      NaN     NaN
# 10  10.0   Yayan Tisna Permadi     NaN       v      NaN        v     NaN
# 11  11.0           Ani Yuanita     NaN     NaN      NaN        v       v
# 12  12.0       Burhan Fajar P.       v     NaN        v      NaN       v
# 13  13.0        Heri Budiyanto     NaN       v      NaN      NaN       v
# 14  14.0       Dimas Satrio W.     NaN       v      NaN        v     NaN
# 15  15.0           Nur Hidayat     NaN       v      NaN      NaN       v
#
#    SUSU[T] MENTEGA[Y] MENTEGA[T]
# 0    Tidak         Ya      Tidak
# 1      NaN        NaN          v
# 2      NaN        NaN          v
# 3        v        NaN          v
# 4      NaN        NaN        NaN
# 5      NaN          v        NaN
# 6      NaN          v        NaN
# 7        v          v        NaN
# 8        v        NaN        NaN
# 9      NaN        NaN        NaN
# 10       v        NaN          v
# 11     NaN        NaN        NaN
# 12     NaN          v        NaN
# 13     NaN        NaN          v
# 14       v        NaN        NaN
# 15     NaN        NaN        NaN

# %%
import sys

from itertools import chain, combinations
from collections import defaultdict
from optparse import OptionParser
from operator import mul

# %%
def subsets(arr):
    """ Returns non empty subsets of arr"""
    return chain(*[combinations(arr, i + 1) for i, a in enumerate(arr)])

def returnItemsWithMinSupport(itemSet, transactionList, minSupport, freqSet):
        """calculates the support for items in the itemSet and returns a subset
       of the itemSet each of whose elements satisfies the minimum support"""
        _itemSet = set()
        localSet = defaultdict(int)

        for item in itemSet:
                for transaction in transactionList:
                        if item.issubset(transaction):
                                freqSet[item] += 1
                                localSet[item] += 1

        for item, count in localSet.items():
                support = float(count)/len(transactionList)

                if support >= minSupport:
                        _itemSet.add(item)

        return _itemSet
def joinSet(itemSet, length):
        """Join a set with itself and returns the n-element itemsets"""
        return set([i.union(j) for i in itemSet for j in itemSet if len(i.union(j)) == length])

def getItemSetTransactionList(data_iterator):
    transactionList = list()
    itemSet = set()
    for record in data_iterator:
        transaction = frozenset(record)
        transactionList.append(transaction)
        for item in transaction:
            itemSet.add(frozenset([item]))              # Generate 1-itemSets
    return itemSet, transactionList

def runApriori(data_iter, minSupport, minConfidence):
    """
    run the apriori algorithm. data_iter is a record iterator
    Return both:
     - items (tuple, support)
     - rules ((pretuple, posttuple), confidence)
    """
    itemSet, transactionList = getItemSetTransactionList(data_iter)

    freqSet = defaultdict(int)
    largeSet = dict()
    # Global dictionary which stores (key=n-itemSets,value=support)
    # which satisfy minSupport

    assocRules = dict()
    # Dictionary which stores Association Rules

    oneCSet = returnItemsWithMinSupport(itemSet,
                                        transactionList,
                                        minSupport,
                                        freqSet)

    currentLSet = oneCSet
    k = 2
    while(currentLSet != set([])):
        largeSet[k-1] = currentLSet
        currentLSet = joinSet(currentLSet, k)
        currentCSet = returnItemsWithMinSupport(currentLSet,
                                                transactionList,
                                                minSupport,
                                                freqSet)
        currentLSet = currentCSet
        k = k + 1

    def getSupport(item):
            """local function which Returns the support of an item"""
            return float(freqSet[item])/len(transactionList)

    toRetItems = []
    for key, value in largeSet.items():
        toRetItems.extend([(tuple(item), getSupport(item))
                           for item in value])

    toRetRules = []
    for key, value in largeSet.items():
        for item in value:
            _subsets = map(frozenset, [x for x in subsets(item)])
            for element in _subsets:
                remain = item.difference(element)
                if len(remain) > 0:
                    confidence = getSupport(item)/getSupport(element)
                    if confidence >= minConfidence:
                        toRetRules.append(((tuple(element), tuple(remain)),
                                           confidence))
    return toRetItems, toRetRules

import operator
def printResults(items, rules):
    for item, support in sorted(items, key=operator.itemgetter(1)):
        print("item: %s , %.3f" % (str(item), support))
    print("\n------------------------ RULES:")
    for rule, confidence in sorted(rules, key=operator.itemgetter(1)):
        pre, post = rule
        print("Rule: %s ==> %s , %.3f" % (str(pre), str(post), confidence))
        
def getSupportAimplikasiB(A, B):
    rule = list(A)
    dict_support = B
    result = 0
    for index_dict_support in dict_support:
        list_index_dict_support = list(index_dict_support)
        check = []
        for data_index in list_index_dict_support:
            if data_index in rule and len(list_index_dict_support) >= len(rule):
                check.append(True)
            else:
                check.append(False)
        if(reduce(mul, check, 1)==True):
#             print(list_index_dict_support)
#             print(dict_support[index_dict_support])
            result = dict_support[index_dict_support]
    
    return result

def dataFromFile(fname):
        """Function which reads from the file and yields a generator"""
        file_iter = open(fname, 'rU')
        for line in file_iter:
                line = line.strip().rstrip(',')                         # Remove trailing comma
                record = frozenset(line.split(','))
                yield record

# %%
list_data, temp_data = [], []

for index, data in df.iterrows():
    if (data['ROTI[Y]'] == None) & (data['ROTI[T]'] == None):
        temp_data.append('ROTI[B]')
    elif data['ROTI[Y]'] == 'v':
        temp_data.append('ROTI[Y]')
    else:
        temp_data.append('ROTI[T]')
    
    if (data['SELAI[Y]'] == None) & (data['SELAI[T]'] == None):
        temp_data.append('SELAI[B]')
    elif data['SELAI[Y]'] == 'v':
        temp_data.append('SELAI[Y]')
    else:
        temp_data.append('SELAI[T]')
        
    if (data['SUSU[Y]'] == None) & (data['SUSU[T]'] == None):
        temp_data.append('SUSU[B]')
    elif data['SUSU[Y]'] == 'v':
        temp_data.append('SUSU[Y]')
    else:
        temp_data.append('SUSU[T]')
        
    if (data['MENTEGA[Y]'] == None) & (data['MENTEGA[T]'] == None):
        temp_data.append('MENTEGA[B]')
    elif data['MENTEGA[Y]'] == 'v':
        temp_data.append('MENTEGA[Y]')
    else:
        temp_data.append('MENTEGA[T]')
    
    list_data.append(temp_data)
    temp_data = []

# %%
minSupport = 0.1
minConfidence = 0.2

items, rules = runApriori(list_data, minSupport, minConfidence)
printResults(items, rules)
# Out:
# item: ('SUSU[T]', 'MENTEGA[Y]') , 0.125
# item: ('ROTI[Y]', 'SELAI[T]') , 0.125
# item: ('ROTI[Y]', 'MENTEGA[T]') , 0.125
# item: ('SUSU[Y]', 'MENTEGA[Y]') , 0.125
# item: ('SUSU[Y]', 'ROTI[Y]', 'MENTEGA[Y]') , 0.125
# item: ('SUSU[Y]', 'ROTI[Y]', 'SELAI[T]') , 0.125
# item: ('SUSU[T]', 'MENTEGA[Y]', 'SELAI[Y]') , 0.125
# item: ('SUSU[T]', 'MENTEGA[Y]', 'ROTI[Y]') , 0.125
# item: ('SUSU[T]', 'ROTI[Y]', 'MENTEGA[Y]', 'SELAI[Y]') , 0.125
# item: ('SUSU[Y]', 'ROTI[Y]') , 0.188
# item: ('SUSU[T]', 'SELAI[Y]') , 0.188
# item: ('MENTEGA[Y]', 'SELAI[Y]') , 0.188
# item: ('SUSU[T]', 'ROTI[Y]') , 0.188
# item: ('MENTEGA[Y]', 'ROTI[Y]', 'SELAI[Y]') , 0.188
# item: ('SUSU[T]', 'ROTI[Y]', 'SELAI[Y]') , 0.188
# item: ('MENTEGA[Y]',) , 0.250
# item: ('SELAI[Y]',) , 0.250
# item: ('ROTI[Y]', 'SELAI[Y]') , 0.250
# item: ('MENTEGA[Y]', 'ROTI[Y]') , 0.250
# item: ('ROTI[T]', 'SUSU[Y]') , 0.312
# item: ('ROTI[T]', 'SUSU[T]') , 0.312
# item: ('SUSU[T]', 'SELAI[T]') , 0.312
# item: ('ROTI[T]', 'SUSU[T]', 'SELAI[T]') , 0.312
# item: ('ROTI[T]', 'SUSU[Y]', 'SELAI[T]') , 0.312
# item: ('SUSU[T]', 'MENTEGA[T]', 'SELAI[T]') , 0.312
# item: ('ROTI[T]', 'SUSU[Y]', 'MENTEGA[T]') , 0.312
# item: ('ROTI[T]', 'SUSU[T]', 'MENTEGA[T]') , 0.312
# item: ('SUSU[Y]', 'SELAI[T]', 'ROTI[T]', 'MENTEGA[T]') , 0.312
# item: ('SUSU[T]', 'SELAI[T]', 'ROTI[T]', 'MENTEGA[T]') , 0.312
# item: ('ROTI[Y]',) , 0.375
# item: ('SUSU[T]', 'MENTEGA[T]') , 0.375
# item: ('SUSU[Y]', 'MENTEGA[T]') , 0.375
# item: ('SUSU[Y]', 'MENTEGA[T]', 'SELAI[T]') , 0.375
# item: ('SUSU[Y]', 'SELAI[T]') , 0.438
# item: ('SUSU[Y]',) , 0.500
# item: ('SUSU[T]',) , 0.500
# item: ('ROTI[T]',) , 0.625
# item: ('ROTI[T]', 'SELAI[T]') , 0.625
# item: ('ROTI[T]', 'MENTEGA[T]') , 0.625
# item: ('ROTI[T]', 'MENTEGA[T]', 'SELAI[T]') , 0.625
# item: ('MENTEGA[T]', 'SELAI[T]') , 0.688
# item: ('MENTEGA[T]',) , 0.750
# item: ('SELAI[T]',) , 0.750
#
# ------------------------ RULES:
# Rule: ('SUSU[T]',) ==> ('MENTEGA[Y]',) , 0.250
# Rule: ('SUSU[Y]',) ==> ('MENTEGA[Y]',) , 0.250
# Rule: ('SUSU[Y]',) ==> ('MENTEGA[Y]', 'ROTI[Y]') , 0.250
# Rule: ('SUSU[Y]',) ==> ('ROTI[Y]', 'SELAI[T]') , 0.250
# Rule: ('SUSU[T]',) ==> ('MENTEGA[Y]', 'SELAI[Y]') , 0.250
# Rule: ('SUSU[T]',) ==> ('MENTEGA[Y]', 'ROTI[Y]') , 0.250
# Rule: ('SUSU[T]',) ==> ('MENTEGA[Y]', 'ROTI[Y]', 'SELAI[Y]') , 0.250
# Rule: ('SUSU[Y]', 'SELAI[T]') ==> ('ROTI[Y]',) , 0.286
# Rule: ('ROTI[Y]',) ==> ('SELAI[T]',) , 0.333
# Rule: ('ROTI[Y]',) ==> ('MENTEGA[T]',) , 0.333
# Rule: ('ROTI[Y]',) ==> ('SUSU[Y]', 'MENTEGA[Y]') , 0.333
# Rule: ('ROTI[Y]',) ==> ('SUSU[Y]', 'SELAI[T]') , 0.333
# Rule: ('ROTI[Y]',) ==> ('SUSU[T]', 'MENTEGA[Y]') , 0.333
# Rule: ('ROTI[Y]',) ==> ('SUSU[T]', 'MENTEGA[Y]', 'SELAI[Y]') , 0.333
# Rule: ('SUSU[Y]',) ==> ('ROTI[Y]',) , 0.375
# Rule: ('SUSU[T]',) ==> ('SELAI[Y]',) , 0.375
# Rule: ('SUSU[T]',) ==> ('ROTI[Y]',) , 0.375
# Rule: ('SUSU[T]',) ==> ('ROTI[Y]', 'SELAI[Y]') , 0.375
# Rule: ('SELAI[T]',) ==> ('SUSU[T]',) , 0.417
# Rule: ('SELAI[T]',) ==> ('ROTI[T]', 'SUSU[T]') , 0.417
# Rule: ('SELAI[T]',) ==> ('ROTI[T]', 'SUSU[Y]') , 0.417
# Rule: ('MENTEGA[T]',) ==> ('SUSU[T]', 'SELAI[T]') , 0.417
# Rule: ('SELAI[T]',) ==> ('SUSU[T]', 'MENTEGA[T]') , 0.417
# Rule: ('MENTEGA[T]',) ==> ('ROTI[T]', 'SUSU[Y]') , 0.417
# Rule: ('MENTEGA[T]',) ==> ('ROTI[T]', 'SUSU[T]') , 0.417
# Rule: ('SELAI[T]',) ==> ('ROTI[T]', 'SUSU[Y]', 'MENTEGA[T]') , 0.417
# Rule: ('MENTEGA[T]',) ==> ('ROTI[T]', 'SUSU[Y]', 'SELAI[T]') , 0.417
# Rule: ('SELAI[T]',) ==> ('ROTI[T]', 'SUSU[T]', 'MENTEGA[T]') , 0.417
# Rule: ('MENTEGA[T]',) ==> ('ROTI[T]', 'SUSU[T]', 'SELAI[T]') , 0.417
# Rule: ('MENTEGA[T]', 'SELAI[T]') ==> ('SUSU[T]',) , 0.455
# Rule: ('MENTEGA[T]', 'SELAI[T]') ==> ('ROTI[T]', 'SUSU[Y]') , 0.455
# Rule: ('MENTEGA[T]', 'SELAI[T]') ==> ('ROTI[T]', 'SUSU[T]') , 0.455
# Rule: ('MENTEGA[T]',) ==> ('SUSU[T]',) , 0.500
# Rule: ('MENTEGA[Y]',) ==> ('SUSU[T]',) , 0.500
# Rule: ('ROTI[Y]',) ==> ('SUSU[Y]',) , 0.500
# Rule: ('ROTI[T]',) ==> ('SUSU[Y]',) , 0.500
# Rule: ('MENTEGA[Y]',) ==> ('SUSU[Y]',) , 0.500
# Rule: ('ROTI[T]',) ==> ('SUSU[T]',) , 0.500
# Rule: ('MENTEGA[T]',) ==> ('SUSU[Y]',) , 0.500
# Rule: ('ROTI[Y]',) ==> ('SUSU[T]',) , 0.500
# Rule: ('MENTEGA[Y]',) ==> ('SUSU[Y]', 'ROTI[Y]') , 0.500
# Rule: ('MENTEGA[Y]', 'ROTI[Y]') ==> ('SUSU[Y]',) , 0.500
# Rule: ('ROTI[T]',) ==> ('SUSU[T]', 'SELAI[T]') , 0.500
# Rule: ('ROTI[T]', 'SELAI[T]') ==> ('SUSU[T]',) , 0.500
# Rule: ('ROTI[Y]',) ==> ('MENTEGA[Y]', 'SELAI[Y]') , 0.500
# Rule: ('MENTEGA[Y]',) ==> ('SUSU[T]', 'SELAI[Y]') , 0.500
# Rule: ('SELAI[Y]',) ==> ('SUSU[T]', 'MENTEGA[Y]') , 0.500
# Rule: ('ROTI[Y]',) ==> ('SUSU[T]', 'SELAI[Y]') , 0.500
# Rule: ('MENTEGA[Y]',) ==> ('SUSU[T]', 'ROTI[Y]') , 0.500
# Rule: ('MENTEGA[Y]', 'ROTI[Y]') ==> ('SUSU[T]',) , 0.500
# Rule: ('ROTI[T]',) ==> ('SUSU[Y]', 'SELAI[T]') , 0.500
# Rule: ('ROTI[T]', 'SELAI[T]') ==> ('SUSU[Y]',) , 0.500
# Rule: ('ROTI[T]',) ==> ('SUSU[Y]', 'MENTEGA[T]') , 0.500
# Rule: ('ROTI[T]', 'MENTEGA[T]') ==> ('SUSU[Y]',) , 0.500
# Rule: ('MENTEGA[T]',) ==> ('SUSU[Y]', 'SELAI[T]') , 0.500
# Rule: ('SELAI[T]',) ==> ('SUSU[Y]', 'MENTEGA[T]') , 0.500
# Rule: ('ROTI[T]',) ==> ('SUSU[T]', 'MENTEGA[T]') , 0.500
# Rule: ('ROTI[T]', 'MENTEGA[T]') ==> ('SUSU[T]',) , 0.500
# Rule: ('MENTEGA[Y]',) ==> ('SUSU[T]', 'ROTI[Y]', 'SELAI[Y]') , 0.500
# Rule: ('SELAI[Y]',) ==> ('SUSU[T]', 'MENTEGA[Y]', 'ROTI[Y]') , 0.500
# Rule: ('MENTEGA[Y]', 'ROTI[Y]') ==> ('SUSU[T]', 'SELAI[Y]') , 0.500
# Rule: ('ROTI[Y]', 'SELAI[Y]') ==> ('SUSU[T]', 'MENTEGA[Y]') , 0.500
# Rule: ('ROTI[T]',) ==> ('MENTEGA[T]', 'SUSU[Y]', 'SELAI[T]') , 0.500
# Rule: ('ROTI[T]', 'SELAI[T]') ==> ('SUSU[Y]', 'MENTEGA[T]') , 0.500
# Rule: ('ROTI[T]', 'MENTEGA[T]') ==> ('SUSU[Y]', 'SELAI[T]') , 0.500
# Rule: ('ROTI[T]', 'MENTEGA[T]', 'SELAI[T]') ==> ('SUSU[Y]',) , 0.500
# Rule: ('ROTI[T]',) ==> ('SUSU[T]', 'SELAI[T]', 'MENTEGA[T]') , 0.500
# Rule: ('ROTI[T]', 'SELAI[T]') ==> ('SUSU[T]', 'MENTEGA[T]') , 0.500
# Rule: ('ROTI[T]', 'MENTEGA[T]') ==> ('SUSU[T]', 'SELAI[T]') , 0.500
# Rule: ('ROTI[T]', 'MENTEGA[T]', 'SELAI[T]') ==> ('SUSU[T]',) , 0.500
# Rule: ('MENTEGA[T]', 'SELAI[T]') ==> ('SUSU[Y]',) , 0.545
# Rule: ('SELAI[T]',) ==> ('SUSU[Y]',) , 0.583
# Rule: ('SUSU[Y]',) ==> ('ROTI[T]',) , 0.625
# Rule: ('SUSU[T]',) ==> ('ROTI[T]',) , 0.625
# Rule: ('SUSU[T]',) ==> ('SELAI[T]',) , 0.625
# Rule: ('SUSU[T]',) ==> ('ROTI[T]', 'SELAI[T]') , 0.625
# Rule: ('SUSU[Y]',) ==> ('ROTI[T]', 'SELAI[T]') , 0.625
# Rule: ('SUSU[T]',) ==> ('MENTEGA[T]', 'SELAI[T]') , 0.625
# Rule: ('SUSU[Y]',) ==> ('ROTI[T]', 'MENTEGA[T]') , 0.625
# Rule: ('SUSU[T]',) ==> ('ROTI[T]', 'MENTEGA[T]') , 0.625
# Rule: ('SUSU[Y]',) ==> ('ROTI[T]', 'MENTEGA[T]', 'SELAI[T]') , 0.625
# Rule: ('SUSU[T]',) ==> ('ROTI[T]', 'MENTEGA[T]', 'SELAI[T]') , 0.625
# Rule: ('ROTI[Y]',) ==> ('SELAI[Y]',) , 0.667
# Rule: ('ROTI[Y]',) ==> ('MENTEGA[Y]',) , 0.667
# Rule: ('SUSU[Y]', 'ROTI[Y]') ==> ('MENTEGA[Y]',) , 0.667
# Rule: ('SUSU[Y]', 'ROTI[Y]') ==> ('SELAI[T]',) , 0.667
# Rule: ('SUSU[T]', 'SELAI[Y]') ==> ('MENTEGA[Y]',) , 0.667
# Rule: ('MENTEGA[Y]', 'SELAI[Y]') ==> ('SUSU[T]',) , 0.667
# Rule: ('SUSU[T]', 'ROTI[Y]') ==> ('MENTEGA[Y]',) , 0.667
# Rule: ('SUSU[T]', 'ROTI[Y]') ==> ('MENTEGA[Y]', 'SELAI[Y]') , 0.667
# Rule: ('SUSU[T]', 'SELAI[Y]') ==> ('MENTEGA[Y]', 'ROTI[Y]') , 0.667
# Rule: ('MENTEGA[Y]', 'SELAI[Y]') ==> ('SUSU[T]', 'ROTI[Y]') , 0.667
# Rule: ('SUSU[T]', 'ROTI[Y]', 'SELAI[Y]') ==> ('MENTEGA[Y]',) , 0.667
# Rule: ('MENTEGA[Y]', 'ROTI[Y]', 'SELAI[Y]') ==> ('SUSU[T]',) , 0.667
# Rule: ('SUSU[Y]', 'SELAI[T]') ==> ('ROTI[T]',) , 0.714
# Rule: ('SUSU[Y]', 'SELAI[T]') ==> ('ROTI[T]', 'MENTEGA[T]') , 0.714
# Rule: ('SUSU[T]',) ==> ('MENTEGA[T]',) , 0.750
# Rule: ('SELAI[Y]',) ==> ('SUSU[T]',) , 0.750
# Rule: ('MENTEGA[Y]',) ==> ('SELAI[Y]',) , 0.750
# Rule: ('SELAI[Y]',) ==> ('MENTEGA[Y]',) , 0.750
# Rule: ('SUSU[Y]',) ==> ('MENTEGA[T]',) , 0.750
# Rule: ('MENTEGA[Y]',) ==> ('ROTI[Y]', 'SELAI[Y]') , 0.750
# Rule: ('SELAI[Y]',) ==> ('MENTEGA[Y]', 'ROTI[Y]') , 0.750
# Rule: ('MENTEGA[Y]', 'ROTI[Y]') ==> ('SELAI[Y]',) , 0.750
# Rule: ('ROTI[Y]', 'SELAI[Y]') ==> ('MENTEGA[Y]',) , 0.750
# Rule: ('SELAI[Y]',) ==> ('SUSU[T]', 'ROTI[Y]') , 0.750
# Rule: ('ROTI[Y]', 'SELAI[Y]') ==> ('SUSU[T]',) , 0.750
# Rule: ('SUSU[Y]',) ==> ('MENTEGA[T]', 'SELAI[T]') , 0.750
# Rule: ('SELAI[T]',) ==> ('ROTI[T]',) , 0.833
# Rule: ('MENTEGA[T]',) ==> ('ROTI[T]',) , 0.833
# Rule: ('SUSU[T]', 'MENTEGA[T]') ==> ('SELAI[T]',) , 0.833
# Rule: ('SUSU[Y]', 'MENTEGA[T]') ==> ('ROTI[T]',) , 0.833
# Rule: ('SUSU[T]', 'MENTEGA[T]') ==> ('ROTI[T]',) , 0.833
# Rule: ('MENTEGA[T]',) ==> ('ROTI[T]', 'SELAI[T]') , 0.833
# Rule: ('SELAI[T]',) ==> ('ROTI[T]', 'MENTEGA[T]') , 0.833
# Rule: ('SUSU[Y]', 'MENTEGA[T]') ==> ('ROTI[T]', 'SELAI[T]') , 0.833
# Rule: ('MENTEGA[T]', 'SUSU[Y]', 'SELAI[T]') ==> ('ROTI[T]',) , 0.833
# Rule: ('SUSU[T]', 'MENTEGA[T]') ==> ('ROTI[T]', 'SELAI[T]') , 0.833
# Rule: ('SUSU[Y]', 'SELAI[T]') ==> ('MENTEGA[T]',) , 0.857
# Rule: ('SUSU[Y]',) ==> ('SELAI[T]',) , 0.875
# Rule: ('MENTEGA[T]', 'SELAI[T]') ==> ('ROTI[T]',) , 0.909
# Rule: ('MENTEGA[T]',) ==> ('SELAI[T]',) , 0.917
# Rule: ('SELAI[T]',) ==> ('MENTEGA[T]',) , 0.917
# Rule: ('ROTI[T]',) ==> ('SELAI[T]',) , 1.000
# Rule: ('SELAI[Y]',) ==> ('ROTI[Y]',) , 1.000
# Rule: ('MENTEGA[Y]',) ==> ('ROTI[Y]',) , 1.000
# Rule: ('ROTI[T]',) ==> ('MENTEGA[T]',) , 1.000
# Rule: ('SUSU[Y]', 'MENTEGA[Y]') ==> ('ROTI[Y]',) , 1.000
# Rule: ('ROTI[Y]', 'SELAI[T]') ==> ('SUSU[Y]',) , 1.000
# Rule: ('ROTI[T]', 'SUSU[T]') ==> ('SELAI[T]',) , 1.000
# Rule: ('SUSU[T]', 'SELAI[T]') ==> ('ROTI[T]',) , 1.000
# Rule: ('MENTEGA[Y]', 'SELAI[Y]') ==> ('ROTI[Y]',) , 1.000
# Rule: ('SUSU[T]', 'MENTEGA[Y]') ==> ('SELAI[Y]',) , 1.000
# Rule: ('SUSU[T]', 'ROTI[Y]') ==> ('SELAI[Y]',) , 1.000
# Rule: ('SUSU[T]', 'SELAI[Y]') ==> ('ROTI[Y]',) , 1.000
# Rule: ('SUSU[T]', 'MENTEGA[Y]') ==> ('ROTI[Y]',) , 1.000
# Rule: ('ROTI[T]', 'SUSU[Y]') ==> ('SELAI[T]',) , 1.000
# Rule: ('SUSU[T]', 'SELAI[T]') ==> ('MENTEGA[T]',) , 1.000
# Rule: ('ROTI[T]', 'SUSU[Y]') ==> ('MENTEGA[T]',) , 1.000
# Rule: ('SUSU[Y]', 'MENTEGA[T]') ==> ('SELAI[T]',) , 1.000
# Rule: ('ROTI[T]', 'SUSU[T]') ==> ('MENTEGA[T]',) , 1.000
# Rule: ('ROTI[T]',) ==> ('MENTEGA[T]', 'SELAI[T]') , 1.000
# Rule: ('ROTI[T]', 'MENTEGA[T]') ==> ('SELAI[T]',) , 1.000
# Rule: ('ROTI[T]', 'SELAI[T]') ==> ('MENTEGA[T]',) , 1.000
# Rule: ('SUSU[T]', 'MENTEGA[Y]') ==> ('ROTI[Y]', 'SELAI[Y]') , 1.000
# Rule: ('SUSU[T]', 'MENTEGA[Y]', 'ROTI[Y]') ==> ('SELAI[Y]',) , 1.000
# Rule: ('SUSU[T]', 'MENTEGA[Y]', 'SELAI[Y]') ==> ('ROTI[Y]',) , 1.000
# Rule: ('ROTI[T]', 'SUSU[Y]') ==> ('MENTEGA[T]', 'SELAI[T]') , 1.000
# Rule: ('ROTI[T]', 'SUSU[Y]', 'SELAI[T]') ==> ('MENTEGA[T]',) , 1.000
# Rule: ('ROTI[T]', 'SUSU[Y]', 'MENTEGA[T]') ==> ('SELAI[T]',) , 1.000
# Rule: ('SUSU[T]', 'SELAI[T]') ==> ('ROTI[T]', 'MENTEGA[T]') , 1.000
# Rule: ('ROTI[T]', 'SUSU[T]') ==> ('MENTEGA[T]', 'SELAI[T]') , 1.000
# Rule: ('ROTI[T]', 'SUSU[T]', 'SELAI[T]') ==> ('MENTEGA[T]',) , 1.000
# Rule: ('SUSU[T]', 'SELAI[T]', 'MENTEGA[T]') ==> ('ROTI[T]',) , 1.000
# Rule: ('ROTI[T]', 'SUSU[T]', 'MENTEGA[T]') ==> ('SELAI[T]',) , 1.000
